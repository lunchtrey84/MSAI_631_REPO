# %% [markdown]
# <a href="https://colab.research.google.com/github/lunchtrey84/MSAI_631_REPO/blob/main/MSAI631_Development_Environment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# Define the number of rows and columns for the DataFrame
num_rows = 5
num_cols = 3

# Create a dictionary to hold random data for each column
data = {
    f'Column_{i+1}': np.random.rand(num_rows) for i in range(num_cols)
}

# Create the DataFrame
df = pd.DataFrame(data)

# Display the DataFrame
print(df)
# Out:
#    Column_1  Column_2  Column_3
# 0  0.889040  0.299274  0.943494
# 1  0.116923  0.912487  0.622501
# 2  0.200892  0.748381  0.648551
# 3  0.333487  0.347959  0.244702
# 4  0.464340  0.848194  0.054494

# %%
import pandas as pd

import numpy as np

#Define Hello World

print("Hello, World!")
# Out:
# Hello, World!
